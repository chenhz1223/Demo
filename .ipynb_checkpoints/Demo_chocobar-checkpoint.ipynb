# %%
using Pkg
Pkg.activate(temp = true)

using CSV
using DataFrames
using Statistics
using StatsBase
using Plots
using StatsPlots
using GLM, StatsModels
# Out:
#   Activating new project at `/var/folders/rh/_vq019gj58bfk4ld168m8b700000gn/T/jl_aU62cP`

# %%
C = CSV.read("data/chocoBarRating.csv", DataFrame);

# %%
names(C)
# Out:
# 9-element Vector{String}:
#  "Company"
#  "Name"
#  "Ref"
#  "Review Date"
#  "Cocoa_Percent"
#  "Company_Location"
#  "Rating"
#  "Broad_Bean_Origin"
#  "Bean_Type"

# %%
println(size(C))
# Out:
# (1708, 9)

# %%
describe(C)
# Out:
# 9×7 DataFrame
#  Row │ variable           mean     min                          median  max    ⋯
#      │ Symbol             Union…   Any                          Union…  Any    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Company                     A. Morin                             twenty ⋯
#    2 │ Name                        "heirloom", Arriba Nacional          the lo
#    3 │ Ref                991.406  5                            1026.0  1864
#    4 │ Review Date        2012.12  2006                         2013.0  2016
#    5 │ Cocoa_Percent      71.7242  42                           70.0    100    ⋯
#    6 │ Company_Location            Amsterdam                            Wales
#    7 │ Rating             3.18238  1.0                          3.25    5.0
#    8 │ Broad_Bean_Origin           Africa, Carribean, C. Am.            West A
#    9 │ Bean_Type                   Amazon                               Trinit ⋯
# ...

# %%
boxplot(C.Rating, title = "Box Plot - Rating", ylabel = "Rating", legend = false)

# %%
density(C.Rating , title = "Density Plot - Rating", ylabel = "Frequency", xlabel = "Rating", legend = false)

# %%
@df C scatter([:Ref :Cocoa_Percent ], [:Rating :Rating],
           smooth=true,
           line = :red,
           linewidth = 2,
           title= [i for i in 1:2],
           legend = false,
           layout = 2)

# %%
scatter(C.Cocoa_Percent,C.Rating,xlabel="cocoa_percent",
    ylabel="rating",legend=false,grid=false,size=(400,300))

# %%
linearmodel = fit(LinearModel, @formula(Rating ~ Ref+Cocoa_Percent+Company_Location), C)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Vector{Float64}}, GLM.DensePredChol{Float64, LinearAlgebra.CholeskyPivoted{Float64, Matrix{Float64}}}}, Matrix{Float64}}
#
# Rating ~ 1 + Ref + Cocoa_Percent + Company_Location
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                             Coef.  Std. Error      t  Pr(>|t|)    Lower 95%    Upper 95%
# ────────────────────────────────────────────────────────────────────────────────────────────────────────
# (Intercept)                           4.28879      0.269422    15.92    <1e-52   3.76034      4.81723
# Ref                                   0.000137606  2.46374e-5   5.59    <1e-07   8.92818e-5   0.00018593
# Cocoa_Percent                        -0.0137169    0.00181616  -7.55    <1e-13  -0.0172791   -0.0101546
# Company_Location: Argentina          -0.0217758    0.281404    -0.08    0.9383  -0.573723     0.530171
# ...
